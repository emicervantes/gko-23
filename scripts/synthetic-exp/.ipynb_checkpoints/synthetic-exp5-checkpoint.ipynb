# %%
# Load libraries
import pandas as pd
import numpy as np
from time import process_time
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import random
import math
from numpy.random import default_rng
from sklearn.preprocessing import normalize
import matplotlib.pyplot as plt
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# # Gaussian System

# %%
# Generate System
A = np.random.randn(5000,500)
x = np.ones(500)
y = A @ x
TOL = 10**-4

# %%
# Find the minimum singular value
U,S,V = np.linalg.svd(A)
S2_min = min(S**2)
# Find the max angle
inner_p = A@np.transpose(A)
lower = inner_p[np.triu_indices(500, k = 1)]
angles_g = np.sin(lower)**2
# Find the row norm
row_norm_g = np.sum(np.abs(A)**2,axis=-1)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
plt.hist(angles_g)
# Out:
# (array([25683., 11425.,  9190.,  8230.,  7836.,  7938.,  8326.,  9355.,
#         11159., 25608.]),
#  array([5.0410947e-10, 1.0000000e-01, 2.0000000e-01, 3.0000000e-01,
#         4.0000000e-01, 5.0000000e-01, 6.0000000e-01, 7.0000000e-01,
#         8.0000000e-01, 9.0000000e-01, 1.0000000e+00]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(row_norm_g)
# Out:
# (array([   8.,   28.,  263.,  781., 1357., 1349.,  817.,  312.,   65.,
#           20.]),
#  array([379.56531677, 403.38474886, 427.20418095, 451.02361305,
#         474.84304514, 498.66247724, 522.48190933, 546.30134142,
#         570.12077352, 593.94020561, 617.75963771]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Uniform System

# %%
# Generate System
A = np.random.uniform(low = 0, high = 1, size  = (5000,500))
x = np.ones(500)
y = A @ x

# %%
# Find the minimum singular value
U,S,V = np.linalg.svd(A)
S2_min = min(S**2)
# Find the max angle
inner_p = A@np.transpose(A)
lower = inner_p[np.triu_indices(500, k = 1)]
angles_u = np.sin(lower)**2
# Find the row norm
row_norm_u = np.sum(np.abs(A)**2,axis=-1)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
plt.hist(angles_u)
# Out:
# (array([25438., 11343.,  9305.,  8330.,  7914.,  7976.,  8370.,  9210.,
#         11431., 25433.]),
#  array([1.65915149e-10, 1.00000000e-01, 2.00000000e-01, 3.00000000e-01,
#         4.00000000e-01, 5.00000000e-01, 6.00000000e-01, 7.00000000e-01,
#         8.00000000e-01, 9.00000000e-01, 1.00000000e+00]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(row_norm_u)
# Out:
# (array([   7.,   54.,  316., 1066., 1638., 1287.,  495.,  123.,   12.,
#            2.]),
#  array([140.74089552, 146.30298313, 151.86507073, 157.42715833,
#         162.98924593, 168.55133354, 174.11342114, 179.67550874,
#         185.23759634, 190.79968395, 196.36177155]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Mixture Systems

# %% [markdown]
# ## 50/50

# %%
# generate system
A1 = np.random.rand(2500,500)
A2 = np.random.uniform(low = 0, high = 1, size  = (2500,500))
A = np.concatenate((A1, A2))
x = np.ones(500)
y = A @ x

# %%
# Find the minimum singular value
U,S,V = np.linalg.svd(A)
S2_min = min(S**2)
# Find the max angle
inner_p = A@np.transpose(A)
lower = inner_p[np.triu_indices(500, k = 1)]
angles_gu1 = np.sin(lower)**2
# Find the row norm
row_norm_gu1 = np.sum(np.abs(A)**2,axis=-1)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
plt.hist(angles_gu1)
# Out:
# (array([25551., 11249.,  9186.,  8388.,  8066.,  7841.,  8302.,  9313.,
#         11413., 25441.]),
#  array([2.16131031e-11, 1.00000000e-01, 2.00000000e-01, 3.00000000e-01,
#         4.00000000e-01, 5.00000000e-01, 6.00000000e-01, 7.00000000e-01,
#         8.00000000e-01, 9.00000000e-01, 9.99999999e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(row_norm_gu1)
# Out:
# (array([  13.,   81.,  372.,  803., 1234., 1208.,  828.,  340.,  105.,
#           16.]),
#  array([144.35059913, 148.80597204, 153.26134496, 157.71671787,
#         162.17209079, 166.6274637 , 171.08283662, 175.53820953,
#         179.99358245, 184.44895536, 188.90432828]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## 25/75

# %%
# generate system
A1 = np.random.rand(1250,500)
A2 = np.random.uniform(low = 0, high = 1, size  = (3750,500))
A = np.concatenate((A1, A2))
x = np.ones(500)
y = A @ x

# %%
# Find the minimum singular value
U,S,V = np.linalg.svd(A)
S2_min = min(S**2)
# Find the max angle
inner_p = A@np.transpose(A)
lower = inner_p[np.triu_indices(500, k = 1)]
angles_gu2 = np.sin(lower)**2
# Find the row norm
row_norm_gu2 = np.sum(np.abs(A)**2,axis=-1)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
plt.hist(angles_gu2)
# Out:
# (array([25619., 11322.,  9165.,  8326.,  8138.,  7987.,  8170.,  9140.,
#         11370., 25513.]),
#  array([1.68299933e-11, 1.00000000e-01, 2.00000000e-01, 3.00000000e-01,
#         4.00000000e-01, 5.00000000e-01, 6.00000000e-01, 7.00000000e-01,
#         8.00000000e-01, 9.00000000e-01, 1.00000000e+00]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(row_norm_gu2)
# Out:
# (array([   5.,   71.,  294.,  763., 1205., 1297.,  879.,  368.,   95.,
#           23.]),
#  array([143.30868881, 147.88473538, 152.46078195, 157.03682851,
#         161.61287508, 166.18892165, 170.76496822, 175.34101478,
#         179.91706135, 184.49310792, 189.06915449]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## 75/25

# %%
# generate system
A1 = np.random.rand(3750,500)
A2 = np.random.uniform(low = 0, high = 1, size  = (1250,500))
A = np.concatenate((A1, A2))
x = np.ones(500)
y = A @ x

# %%
# Find the minimum singular value
U,S,V = np.linalg.svd(A)
S2_min = min(S**2)
# Find the max angle
inner_p = A@np.transpose(A)
lower = inner_p[np.triu_indices(500, k = 1)]
angles_gu3 = np.sin(lower)**2
# Find the row norm
row_norm_gu3 = np.sum(np.abs(A)**2,axis=-1)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
plt.hist(angles_gu3)
# Out:
# (array([25569., 11235.,  9191.,  8471.,  8054.,  7917.,  8281.,  9302.,
#         11298., 25432.]),
#  array([1.20739349e-10, 1.00000000e-01, 2.00000000e-01, 3.00000000e-01,
#         4.00000000e-01, 5.00000000e-01, 6.00000000e-01, 7.00000000e-01,
#         8.00000000e-01, 9.00000000e-01, 1.00000000e+00]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(row_norm_gu3)
# Out:
# (array([   8.,   45.,  253.,  679., 1204., 1349.,  931.,  401.,  112.,
#           18.]),
#  array([142.05999227, 146.7752258 , 151.49045933, 156.20569287,
#         160.9209264 , 165.63615994, 170.35139347, 175.06662701,
#         179.78186054, 184.49709407, 189.21232761]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # 2 Highly Correlated Systems

# %%
# generate system
# Step 1: generate two gaussian linear system
A = np.random.randn(2,500)
A1 = np.reshape(A[0,:], (1, 500))
A2 = np.reshape(A[1,:], (1, 500))
# Step 2: generate correalted systems
U = np.random.uniform(low = 0, high = 1, size  = (2500,500))
A1 =  np.tile(A1, (2500, 1)) +  U
A2 =  np.tile(A2, (2500, 1)) +  U
# Step 3: Combine two correlated systems
A = np.concatenate((A1, A2))
x = np.ones(500)
y = A @ x

# %%
# Find the minimum singular value
U,S,V = np.linalg.svd(A)
S2_min = min(S**2)
# Find the max angle
inner_p = A@np.transpose(A)
lower = inner_p[np.triu_indices(500, k = 1)]
angles_corr = np.sin(lower)**2
# Find the row norm
row_norm_corr = np.sum(np.abs(A)**2,axis=-1)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
plt.hist(angles_corr)
# Out:
# (array([25559., 11400.,  9190.,  8213.,  7905.,  7897.,  8454.,  9140.,
#         11240., 25752.]),
#  array([1.01937960e-09, 1.00000001e-01, 2.00000001e-01, 3.00000001e-01,
#         4.00000001e-01, 5.00000000e-01, 6.00000000e-01, 7.00000000e-01,
#         8.00000000e-01, 9.00000000e-01, 1.00000000e+00]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(row_norm_corr)
# Out:
# (array([ 28., 273., 901., 948., 412., 525., 965., 741., 189.,  18.]),
#  array([588.03740943, 603.72321795, 619.40902647, 635.09483499,
#         650.78064351, 666.46645203, 682.15226055, 697.83806907,
#         713.52387759, 729.20968611, 744.89549463]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Results

# %%
plt.hist(row_norm_g, label = "Gaussian",  alpha = 0.5, edgecolor = "black")
plt.hist(row_norm_u, label = "Uniform", alpha = 0.5, edgecolor = "black")
plt.hist(row_norm_gu1, label = "50/50 Gaussian-Uniform", alpha = 0.5, edgecolor = "black")
plt.hist(row_norm_gu2, label = "25/75 Gaussian-Uniform", alpha = 0.5, edgecolor = "black")
plt.hist(row_norm_gu3, label = "75/25 Gaussian-Uniform", alpha = 0.5, edgecolor = "black")
plt.hist(row_norm_corr, label = "2 Correlated Systems", alpha = 0.5, edgecolor = "black")
plt.ylabel('Count', fontsize = 10)
plt.xlabel('$||a_i||^2$', fontsize = 10)
plt.title('Distribution of $||a_i||^2$', fontweight="bold")
plt.legend()

# %%
plt.hist(angles_g, label = "Gaussian",  alpha = 0.2, edgecolor = "black")
plt.hist(angles_u, label = "Uniform", alpha = 0.2, edgecolor = "black")
plt.hist(angles_gu1, label = "50/50 Gaussian-Uniform", alpha = 0.2, edgecolor = "black")
plt.hist(angles_gu2, label = "25/75 Gaussian-Uniform", alpha = 0.2, edgecolor = "black")
plt.hist(angles_gu3, label = "75/25 Gaussian-Uniform", alpha = 0.2, edgecolor = "black")
plt.hist(angles_corr, label = "2 Correlated Systems", alpha = 0.2, edgecolor = "black")
plt.ylabel('Count', fontsize = 10)
plt.xlabel('Angles', fontsize = 10)
plt.title('Distribution of Angles', fontweight="bold")
plt.legend()
