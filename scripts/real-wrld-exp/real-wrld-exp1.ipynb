# %%
# importing necessary libraries
from time import process_time
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import random
import math
from scipy import sparse
from scipy.sparse import random
from scipy import stats
from numpy.random import default_rng
from sklearn.preprocessing import normalize
import numpy as np
import os
import pandas as pd

# %%
# importing algorithm functions
import sys
sys.path.insert(1, '../functions')
from gk import gk
from mwrko import mwrko
from gko import gko

# %%
# import data
import scipy.io
divorce = scipy.io.loadmat('../../data/divorce.mat')
stranke = scipy.io.loadmat('../../data/Stranke94.mat')
ash958 = scipy.io.loadmat('../../data/ash958.mat')
well1850 = scipy.io.loadmat('../../data/well1850.mat')
maragal4 = scipy.io.loadmat('../../data/Maragal_4.mat')

# %% [markdown]
# ### Divorce Dataset

# %%
div = (divorce['Problem'][0][0]['A'])
div = div.toarray()
x = np.random.rand(9)
#div = normalize(div, axis=1, norm='l2')
y = div @ x

# %%
# gk
gk_start_cyclic_div = process_time()
gk_div = gk(div,x,y, 0.5*10**-5)
gk_stop_cyclic_div = process_time()
# gko
gko_start_cyclic_div = process_time()
gko_div = gko(div,x,y, 0.5*10**-5)
gko_stop_cyclic_div = process_time()
# mwrko
mwrko_start_cyclic_div = process_time()
mwrko_div = mwrko(div,x,y, 0.5*10**-5)
mwrko_stop_cyclic_div = process_time()

# %%
# Store CPU data
gk_cpu_div = gk_stop_cyclic_div - gk_start_cyclic_div
gko_cpu_div = gko_stop_cyclic_div - gko_start_cyclic_div
mwrko_cpu_div = mwrko_stop_cyclic_div - mwrko_start_cyclic_div

# %%
# Iteration
plt.figure(figsize=(10,7))

plt.semilogy(np.arange(gk_div[0]), gk_div[1],color = '#1E88E5', 
             linewidth = 3, linestyle = 'solid', label = 'GK')
plt.semilogy(np.arange(gko_div[0]), gko_div[1],color = '#D81B60', 
             linewidth = 3, linestyle = 'dotted', label = 'GKO')
plt.semilogy(np.arange(mwrko_div[0]), mwrko_div[1],color = '#FFC107',
             linewidth = 3, linestyle = 'dashed', label = 'MWRKO')

plt.xlabel('IT', fontsize = 15)
plt.ylabel('AR', fontsize = 15)
plt.title('Iterations vs. Approximation Error (Divorce Data)', 
         fontsize = 15, fontweight="bold")
plt.legend(fontsize="15")

# %%
# CPU
plt.figure(figsize=(10,7))

plt.semilogy(np.linspace(0,gk_cpu_div,gk_div[0]), gk_div[1], color = '#1E88E5', 
             linewidth = 3, linestyle = 'solid', label = 'GK')
plt.semilogy(np.linspace(0,gko_cpu_div,gko_div[0]), gko_div[1], color = '#D81B60', 
             linewidth = 3, linestyle = 'dotted', label = 'GKO')
plt.semilogy(np.linspace(0,mwrko_cpu_div,mwrko_div[0]), mwrko_div[1],color = '#FFC107',
             linewidth = 3, linestyle = 'dashed', label = 'MWRKO')

plt.xlabel('CPU', fontsize = 15)
plt.ylabel('AR', fontsize = 15)
plt.title('CPU vs. Approximation Error (Divorce Data)', 
         fontsize = 15, fontweight="bold")
plt.legend(fontsize="15")

# %% [markdown]
# ### Stranke Data

# %%
stran = (stranke['Problem'][0][0]['A'])
stran = stran.toarray()
x = np.random.rand(10)
#div = normalize(div, axis=1, norm='l2')
y = stran @ x

# %%
# gk
gk_start_cyclic_stran = process_time()
gk_stran = gk(stran,x,y, 0.5*10**-5)
gk_stop_cyclic_stran = process_time()
# gko
gko_start_cyclic_stran = process_time()
gko_stran = gko(stran,x,y, 0.5*10**-5)
gko_stop_cyclic_stran = process_time()
# mwrko
mwrko_start_cyclic_stran = process_time()
mwrko_stran = mwrko(stran,x,y, 0.5*10**-5)
mwrko_stop_cyclic_stran = process_time()

# %%
# Store CPU data
gk_cpu_stran = gk_stop_cyclic_stran - gk_start_cyclic_stran
gko_cpu_stran = gko_stop_cyclic_stran - gko_start_cyclic_stran
mwrko_cpu_stran = mwrko_stop_cyclic_stran - mwrko_start_cyclic_stran

# %%
# iteration
plt.figure(figsize=(10,7))

plt.semilogy(np.arange(gk_stran[0]), gk_stran[1],color = '#1E88E5', 
             linewidth = 3, linestyle = 'solid', label = 'GK')
plt.semilogy(np.arange(gko_stran[0]), gko_stran[1],color = '#D81B60', 
             linewidth = 3, linestyle = 'dotted', label = 'GKO')
plt.semilogy(np.arange(mwrko_stran[0]), mwrko_stran[1],color = '#FFC107',
             linewidth = 3, linestyle = 'dashed', label = 'MWRKO')

plt.xlabel('IT', fontsize = 15)
plt.ylabel('AR', fontsize = 15)
plt.title('Iterations vs. Approximation Error (Stranke Data)', 
         fontsize = 15, fontweight="bold")
plt.legend(fontsize="15")

# %%
# CPU
plt.figure(figsize=(10,7))

plt.semilogy(np.linspace(0,gk_cpu_stran,gk_stran[0]), gk_stran[1], color = '#1E88E5', 
             linewidth = 3, linestyle = 'solid', label = 'GK')
plt.semilogy(np.linspace(0,gko_cpu_stran,gko_stran[0]), gko_stran[1], color = '#D81B60', 
             linewidth = 3, linestyle = 'dotted', label = 'GKO')
plt.semilogy(np.linspace(0,mwrko_cpu_stran,mwrko_stran[0]), mwrko_stran[1],color = '#FFC107',
             linewidth = 3, linestyle = 'dashed', label = 'MWRKO')

plt.xlabel('CPU', fontsize = 15)
plt.ylabel('AR', fontsize = 15)
plt.title('CPU vs. Approximation Error (Stranke Data)', 
         fontsize = 15, fontweight="bold")
plt.legend(fontsize="15")

# %% [markdown]
# ### ash958 Data

# %%
ash = (ash958['Problem'][0][0]['A'])
ash = ash.toarray()
x = np.random.rand(292)
y = ash @ x

# %%
# gk
gk_start_cyclic_ash = process_time()
gk_ash = gk(ash,x,y, 0.5*10**-5)
gk_stop_cyclic_ash = process_time()
# gko
gko_start_cyclic_ash = process_time()
gko_ash = gko(ash,x,y, 0.5*10**-5)
gko_stop_cyclic_ash = process_time()
# mwrko
mwrko_start_cyclic_ash = process_time()
mwrko_ash = mwrko(ash,x,y, 0.5*10**-5)
mwrko_stop_cyclic_ash = process_time()

# %%
# Store CPU data
gk_cpu_ash = gk_stop_cyclic_ash - gk_start_cyclic_ash
gko_cpu_ash = gko_stop_cyclic_ash - gko_start_cyclic_ash
mwrko_cpu_ash = mwrko_stop_cyclic_ash - mwrko_start_cyclic_ash

# %%
# iteration
plt.figure(figsize=(10,7))

plt.semilogy(np.arange(gk_ash[0]), gk_ash[1],color = '#1E88E5', 
             linewidth = 3, linestyle = 'solid', label = 'GK')
plt.semilogy(np.arange(gko_ash[0]), gko_ash[1],color = '#D81B60', 
             linewidth = 3, linestyle = 'dotted', label = 'GKO')
plt.semilogy(np.arange(mwrko_ash[0]), mwrko_ash[1],color = '#FFC107',
             linewidth = 3, linestyle = 'dashed', label = 'MWRKO')

plt.xlabel('IT', fontsize = 15)
plt.ylabel('AR', fontsize = 15)
plt.title('Iterations vs. Approximation Error (ash958 Data)', 
         fontsize = 15, fontweight="bold")
plt.legend(fontsize="15")

# %%
# CPU
plt.figure(figsize=(10,7))

plt.semilogy(np.linspace(0,gk_cpu_ash,gk_ash[0]), gk_ash[1], color = '#1E88E5', 
             linewidth = 3, linestyle = 'solid', label = 'GK')
plt.semilogy(np.linspace(0,gko_cpu_ash,gko_ash[0]), gko_ash[1], color = '#D81B60', 
             linewidth = 3, linestyle = 'dotted', label = 'GKO')
plt.semilogy(np.linspace(0,mwrko_cpu_ash,mwrko_ash[0]), mwrko_ash[1],color = '#FFC107',
             linewidth = 3, linestyle = 'dashed', label = 'MWRKO')

plt.xlabel('CPU', fontsize = 15)
plt.ylabel('AR', fontsize = 15)
plt.title('CPU vs. Approximation Error (ash958 Data)', 
         fontsize = 15, fontweight="bold")
plt.legend(fontsize="15")

# %% [markdown]
# ### Overall Results

# %%
# data table
# gk
iter_gk = [gk_div[0], gk_stran[0], gk_ash[0]]
cpu_gk = [gk_cpu_div, gk_cpu_stran, gk_cpu_ash]
# gko
iter_gko = [gko_div[0], gko_stran[0], gko_ash[0]]
cpu_gko = [gko_cpu_div, gko_cpu_stran, gko_cpu_ash]
# mwrko
iter_mwrko = [mwrko_div[0], mwrko_stran[0], mwrko_ash[0]]
cpu_mwrko = [mwrko_cpu_div, mwrko_cpu_stran, mwrko_cpu_ash]

data_lst = ['divorce', 'Stranke94', 'ash958']

df_iter = pd.DataFrame(list(zip(data_lst, iter_gk, iter_gko, iter_mwrko)),
               columns =['Data', 'GK', 'GKO', 'MWRKO'])
df_cpu = pd.DataFrame(list(zip(data_lst, cpu_gk, cpu_gko, cpu_mwrko)),
               columns =['Data', 'GK', 'GKO', 'MWRKO'])

# %%
df_iter
# Out:
#         Data    GK  GKO  MWRKO
# 0    divorce   122   17     34
# 1  Stranke94  4862  607    672
# 2     ash958   869  716    759

# %%
df_cpu
# Out:
#         Data        GK       GKO     MWRKO
# 0    divorce  0.004252  0.001406  0.000842
# 1  Stranke94  0.095930  0.026344  0.014415
# 2     ash958  0.292570  0.510815  0.361832

# %%
# iter
plt.figure(figsize=(100, 70))
fig, (ax1, ax2, ax3)  = plt.subplots(1, 3, sharey='row', figsize=(20, 7))

ax1.semilogy(np.arange(gk_div[0]), gk_div[1],color = '#1E88E5', 
             linewidth = 3, linestyle = 'solid', label = 'GK')
ax1.semilogy(np.arange(gko_div[0]), gko_div[1],color = '#D81B60', 
             linewidth = 3, linestyle = 'dotted', label = 'GKO')
ax1.semilogy(np.arange(mwrko_div[0]), mwrko_div[1],color = '#FFC107',
             linewidth = 3, linestyle = 'dashed', label = 'MWRKO')
ax1.set_title('divorce Data', fontsize=20, fontweight="bold")
ax1.set_xlabel('IT', fontsize=16)
ax1.set_ylabel('AR', fontsize=16)

ax2.semilogy(np.arange(gk_stran[0]), gk_stran[1],color = '#1E88E5', 
             linewidth = 3, linestyle = 'solid', label = 'GK')
ax2.semilogy(np.arange(gko_stran[0]), gko_stran[1],color = '#D81B60', 
             linewidth = 3, linestyle = 'dotted', label = 'GKO')
ax2.semilogy(np.arange(mwrko_stran[0]), mwrko_stran[1],color ='#FFC107',
             linewidth = 3, linestyle = 'dashed', label = 'MWRKO')
ax2.set_title('Stranke94 Data', fontsize=20, fontweight="bold")
ax2.set_xlabel('IT', fontsize=16)
ax2.set_ylabel('AR', fontsize=16)

ax3.semilogy(np.arange(gk_ash[0]), gk_ash[1],color = '#1E88E5', 
             linewidth = 3, linestyle = 'solid', label = 'GK')
ax3.semilogy(np.arange(gko_ash[0]), gko_ash[1],color = '#D81B60', 
             linewidth = 3, linestyle = 'dotted', label = 'GKO')
ax3.semilogy(np.arange(mwrko_ash[0]), mwrko_ash[1],color = '#FFC107',
             linewidth = 3, linestyle = 'dashed', label = 'MWRKO')
ax3.set_title('ash958 Data', fontsize=20, fontweight="bold")
ax3.set_xlabel('IT', fontsize=16)
ax3.set_ylabel('AR', fontsize=16)

plt.legend(fontsize="18")
plt.savefig('../../outputs/real-wrld-exp/real-wrld-iter.png')
plt.show()

# %%
# cpu
plt.figure(figsize=(100, 70))
fig, (ax1, ax2, ax3)  = plt.subplots(1, 3, sharey='row', figsize=(20, 7))

ax1.semilogy(np.linspace(0,gk_cpu_div,gk_div[0]), gk_div[1], color ='#1E88E5', 
             linewidth = 3, linestyle = 'solid', label = 'GK')
ax1.semilogy(np.linspace(0,gko_cpu_div,gko_div[0]), gko_div[1], color = '#D81B60', 
             linewidth = 3, linestyle = 'dotted', label = 'GKO')
ax1.semilogy(np.linspace(0,mwrko_cpu_div,mwrko_div[0]), mwrko_div[1],color = '#FFC107',
             linewidth = 3, linestyle = 'dashed', label = 'MWRKO')
ax1.set_title('divorce Data', fontsize=20, fontweight="bold")
ax1.set_xlabel('CPU', fontsize=16)
ax1.set_ylabel('AR', fontsize=16)

ax2.semilogy(np.linspace(0,gk_cpu_stran,gk_stran[0]), gk_stran[1], color = '#1E88E5', 
             linewidth = 3, linestyle = 'solid', label = 'GK')
ax2.semilogy(np.linspace(0,gko_cpu_stran,gko_stran[0]), gko_stran[1], color = '#D81B60', 
             linewidth = 3, linestyle = 'dotted', label = 'GKO')
ax2.semilogy(np.linspace(0,mwrko_cpu_stran,mwrko_stran[0]), mwrko_stran[1],color = '#FFC107',
             linewidth = 3, linestyle = 'dashed', label = 'MWRKO')
ax2.set_title('Stranke94 Data', fontsize=20, fontweight="bold")
ax2.set_xlabel('CPU', fontsize=16)
ax2.set_ylabel('AR', fontsize=16)

ax3.semilogy(np.linspace(0,gk_cpu_ash,gk_ash[0]), gk_ash[1], color = '#1E88E5', 
             linewidth = 3, linestyle = 'solid', label = 'GK')
ax3.semilogy(np.linspace(0,gko_cpu_ash,gko_ash[0]), gko_ash[1], color = '#D81B60', 
             linewidth = 3, linestyle = 'dotted', label = 'GKO')
ax3.semilogy(np.linspace(0,mwrko_cpu_ash,mwrko_ash[0]), mwrko_ash[1],color = '#FFC107',
             linewidth = 3, linestyle = 'dashed', label = 'MWRKO')
ax3.set_title('ash958 Data', fontsize=20, fontweight="bold")
ax3.set_xlabel('CPU', fontsize=16)
ax3.set_ylabel('AR', fontsize=16)

plt.legend(fontsize="18")
plt.savefig('../../outputs/real-wrld-exp/real-wrld-cpu.png')
plt.show()
